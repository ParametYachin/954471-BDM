# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/credit-card-approval-prediction/credit_record.csv
# /kaggle/input/credit-card-approval-prediction/application_record.csv

# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('../input/credit-card-approval-prediction/application_record.csv',header=0)
df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0               427500.0               Working               Higher education
# 1               427500.0               Working               Higher education
# 2               112500.0               Working  Secondary / secondary special
# 3               270000.0  Commercial associate  Secondary / secondary special
# 4               270000.0  Commercial associate  Secondary / secondary special
# ...                  ...                   ...                            ...
# 438552          135000.0             Pensioner  Secondary / secondary special
# 438553          103500.0               Working  Secondary / secondary special
# 438554           54000.0  Commercial associate               Higher education
# 438555           72000.0             Pensioner  Secondary / secondary special
# 438556          121500.0               Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0             Civil marriage   Rented apartment      -12005          -4542
# 1             Civil marriage   Rented apartment      -12005          -4542
# 2                    Married  House / apartment      -21474          -1134
# 3       Single / not married  House / apartment      -19110          -3051
# 4       Single / not married  House / apartment      -19110          -3051
# ...                      ...                ...         ...            ...
# 438552             Separated  House / apartment      -22717         365243
# 438553  Single / not married  House / apartment      -15939          -3007
# 438554  Single / not married       With parents       -8169           -372
# 438555               Married  House / apartment      -21673         365243
# 438556               Married  House / apartment      -18858          -1201
#
#         FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0                1                1           0           0             NaN
# 1                1                1           0           0             NaN
# 2                1                0           0           0  Security staff
# 3                1                0           1           1     Sales staff
# 4                1                0           1           1     Sales staff
# ...            ...              ...         ...         ...             ...
# 438552           1                0           0           0             NaN
# 438553           1                0           0           0        Laborers
# 438554           1                1           0           0     Sales staff
# 438555           1                0           0           0             NaN
# 438556           1                0           1           0     Sales staff
#
#         CNT_FAM_MEMBERS
# 0                   2.0
# 1                   2.0
# 2                   2.0
# 3                   1.0
# 4                   1.0
# ...                 ...
# 438552              1.0
# 438553              1.0
# 438554              1.0
# 438555              2.0
# 438556              2.0
#
# [438557 rows x 18 columns]

# %%
df.isnull().any()
# Out:
# ID                     False
# CODE_GENDER            False
# FLAG_OWN_CAR           False
# FLAG_OWN_REALTY        False
# CNT_CHILDREN           False
# AMT_INCOME_TOTAL       False
# NAME_INCOME_TYPE       False
# NAME_EDUCATION_TYPE    False
# NAME_FAMILY_STATUS     False
# NAME_HOUSING_TYPE      False
# DAYS_BIRTH             False
# DAYS_EMPLOYED          False
# FLAG_MOBIL             False
# FLAG_WORK_PHONE        False
# FLAG_PHONE             False
# FLAG_EMAIL             False
# OCCUPATION_TYPE         True
# CNT_FAM_MEMBERS        False
# dtype: bool

# %%
df.isnull().sum(axis=0)
# Out:
# ID                          0
# CODE_GENDER                 0
# FLAG_OWN_CAR                0
# FLAG_OWN_REALTY             0
# CNT_CHILDREN                0
# AMT_INCOME_TOTAL            0
# NAME_INCOME_TYPE            0
# NAME_EDUCATION_TYPE         0
# NAME_FAMILY_STATUS          0
# NAME_HOUSING_TYPE           0
# DAYS_BIRTH                  0
# DAYS_EMPLOYED               0
# FLAG_MOBIL                  0
# FLAG_WORK_PHONE             0
# FLAG_PHONE                  0
# FLAG_EMAIL                  0
# OCCUPATION_TYPE        134203
# CNT_FAM_MEMBERS             0
# dtype: int64

# %%
df.groupby('OCCUPATION_TYPE')['OCCUPATION_TYPE'].count()
# Out:
# OCCUPATION_TYPE
# Accountants              15985
# Cleaning staff            5845
# Cooking staff             8076
# Core staff               43007
# Drivers                  26090
# HR staff                   774
# High skill tech staff    17289
# IT staff                   604
# Laborers                 78240
# Low-skill Laborers        2140
# Managers                 35487
# Medicine staff           13520
# Private service staff     3456
# Realty agents             1041
# Sales staff              41098
# Secretaries               2044
# Security staff            7993
# Waiters/barmen staff      1665
# Name: OCCUPATION_TYPE, dtype: int64

# %%
df_clean = df.dropna(axis = 0)

# %%
df_clean_drop = df_clean.drop(['CODE_GENDER','DAYS_BIRTH', 'FLAG_EMAIL', 'FLAG_WORK_PHONE', 'FLAG_PHONE', 'FLAG_MOBIL'],axis = 1)
df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0               427500.0               Working               Higher education
# 1               427500.0               Working               Higher education
# 2               112500.0               Working  Secondary / secondary special
# 3               270000.0  Commercial associate  Secondary / secondary special
# 4               270000.0  Commercial associate  Secondary / secondary special
# ...                  ...                   ...                            ...
# 438552          135000.0             Pensioner  Secondary / secondary special
# 438553          103500.0               Working  Secondary / secondary special
# 438554           54000.0  Commercial associate               Higher education
# 438555           72000.0             Pensioner  Secondary / secondary special
# 438556          121500.0               Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0             Civil marriage   Rented apartment      -12005          -4542
# 1             Civil marriage   Rented apartment      -12005          -4542
# 2                    Married  House / apartment      -21474          -1134
# 3       Single / not married  House / apartment      -19110          -3051
# 4       Single / not married  House / apartment      -19110          -3051
# ...                      ...                ...         ...            ...
# 438552             Separated  House / apartment      -22717         365243
# 438553  Single / not married  House / apartment      -15939          -3007
# 438554  Single / not married       With parents       -8169           -372
# 438555               Married  House / apartment      -21673         365243
# 438556               Married  House / apartment      -18858          -1201
#
#         FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0                1                1           0           0             NaN
# 1                1                1           0           0             NaN
# 2                1                0           0           0  Security staff
# 3                1                0           1           1     Sales staff
# 4                1                0           1           1     Sales staff
# ...            ...              ...         ...         ...             ...
# 438552           1                0           0           0             NaN
# 438553           1                0           0           0        Laborers
# 438554           1                1           0           0     Sales staff
# 438555           1                0           0           0             NaN
# 438556           1                0           1           0     Sales staff
#
#         CNT_FAM_MEMBERS
# 0                   2.0
# 1                   2.0
# 2                   2.0
# 3                   1.0
# 4                   1.0
# ...                 ...
# 438552              1.0
# 438553              1.0
# 438554              1.0
# 438555              2.0
# 438556              2.0
#
# [438557 rows x 18 columns]

# %%
df_clean_drop.isnull().any()
# Out:
# ID                     False
# FLAG_OWN_CAR           False
# FLAG_OWN_REALTY        False
# CNT_CHILDREN           False
# AMT_INCOME_TOTAL       False
# NAME_INCOME_TYPE       False
# NAME_EDUCATION_TYPE    False
# NAME_FAMILY_STATUS     False
# NAME_HOUSING_TYPE      False
# DAYS_EMPLOYED          False
# OCCUPATION_TYPE        False
# CNT_FAM_MEMBERS        False
# dtype: bool

# %%
df_clean_drop.dtypes
# Out:
# ID                       int64
# FLAG_OWN_CAR            object
# FLAG_OWN_REALTY         object
# CNT_CHILDREN             int64
# AMT_INCOME_TOTAL       float64
# NAME_INCOME_TYPE        object
# NAME_EDUCATION_TYPE     object
# NAME_FAMILY_STATUS      object
# NAME_HOUSING_TYPE       object
# DAYS_EMPLOYED            int64
# OCCUPATION_TYPE         object
# CNT_FAM_MEMBERS        float64
# dtype: object

# %%
df_clean_drop['FLAG_OWN_CAR']= pd.factorize(df_clean_drop['OCCUPATION_TYPE'])[0]
df_clean_drop['FLAG_OWN_REALTY']= pd.factorize(df_clean_drop['OCCUPATION_TYPE'])[0]
df_clean_drop['NAME_INCOME_TYPE']= pd.factorize(df_clean_drop['OCCUPATION_TYPE'])[0]
df_clean_drop['NAME_EDUCATION_TYPE']= pd.factorize(df_clean_drop['OCCUPATION_TYPE'])[0]
df_clean_drop['NAME_FAMILY_STATUS']= pd.factorize(df_clean_drop['OCCUPATION_TYPE'])[0]
df_clean_drop['NAME_HOUSING_TYPE']= pd.factorize(df_clean_drop['OCCUPATION_TYPE'])[0]
df_clean_drop['OCCUPATION_TYPE']= pd.factorize(df_clean_drop['OCCUPATION_TYPE'])[0]

# %%
df_clean_drop.dtypes
# Out:
# ID                       int64
# FLAG_OWN_CAR             int64
# FLAG_OWN_REALTY          int64
# CNT_CHILDREN             int64
# AMT_INCOME_TOTAL       float64
# NAME_INCOME_TYPE         int64
# NAME_EDUCATION_TYPE      int64
# NAME_FAMILY_STATUS       int64
# NAME_HOUSING_TYPE        int64
# DAYS_EMPLOYED            int64
# OCCUPATION_TYPE          int64
# CNT_FAM_MEMBERS        float64
# dtype: object

# %%
df_clean_drop
# Out:
#              ID  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 2       5008806             0                0             0
# 3       5008808             1                1             0
# 4       5008809             1                1             0
# 5       5008810             1                1             0
# 6       5008811             1                1             0
# ...         ...           ...              ...           ...
# 438541  6837707             3                3             0
# 438548  6839936             3                3             1
# 438553  6840222             3                3             0
# 438554  6841878             1                1             0
# 438556  6842885             1                1             0
#
#         AMT_INCOME_TOTAL  NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  \
# 2               112500.0                 0                    0
# 3               270000.0                 1                    1
# 4               270000.0                 1                    1
# 5               270000.0                 1                    1
# 6               270000.0                 1                    1
# ...                  ...               ...                  ...
# 438541          202500.0                 3                    3
# 438548          135000.0                 3                    3
# 438553          103500.0                 3                    3
# 438554           54000.0                 1                    1
# 438556          121500.0                 1                    1
#
#         NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_EMPLOYED  OCCUPATION_TYPE  \
# 2                        0                  0          -1134                0
# 3                        1                  1          -3051                1
# 4                        1                  1          -3051                1
# 5                        1                  1          -3051                1
# 6                        1                  1          -3051                1
# ...                    ...                ...            ...              ...
# 438541                   3                  3          -2309                3
# 438548                   3                  3          -2095                3
# 438553                   3                  3          -3007                3
# 438554                   1                  1           -372                1
# 438556                   1                  1          -1201                1
#
#         CNT_FAM_MEMBERS
# 2                   2.0
# 3                   1.0
# 4                   1.0
# 5                   1.0
# 6                   1.0
# ...                 ...
# 438541              2.0
# 438548              3.0
# 438553              1.0
# 438554              1.0
# 438556              2.0
#
# [304354 rows x 12 columns]

# %% [markdown]
# # **** Y

# %%
df_label = pd.read_csv('../input/credit-card-approval-prediction/credit_record.csv',header=0)
df_label
# Out:
#               ID  MONTHS_BALANCE STATUS
# 0        5001711               0      X
# 1        5001711              -1      0
# 2        5001711              -2      0
# 3        5001711              -3      0
# 4        5001712               0      C
# ...          ...             ...    ...
# 1048570  5150487             -25      C
# 1048571  5150487             -26      C
# 1048572  5150487             -27      C
# 1048573  5150487             -28      C
# 1048574  5150487             -29      C
#
# [1048575 rows x 3 columns]

# %%
df_label.groupby('ID')['STATUS'].count()
# Out:
# ID
# 5001711     4
# 5001712    19
# 5001713    22
# 5001714    15
# 5001715    60
#            ..
# 5150482    18
# 5150483    18
# 5150484    13
# 5150485     2
# 5150487    30
# Name: STATUS, Length: 45985, dtype: int64

# %%
df_label['STATUS'], labels  = pd.factorize(df_label['STATUS'])

# %%
labels
# Out:
# Index(['X', '0', 'C', '1', '2', '3', '4', '5'], dtype='object')

# %%
df_label_clean = df_label[df_label['STATUS'] != 0]
df_label_clean
# Out:
#               ID  MONTHS_BALANCE  STATUS
# 1        5001711              -1       1
# 2        5001711              -2       1
# 3        5001711              -3       1
# 4        5001712               0       2
# 5        5001712              -1       2
# ...          ...             ...     ...
# 1048570  5150487             -25       2
# 1048571  5150487             -26       2
# 1048572  5150487             -27       2
# 1048573  5150487             -28       2
# 1048574  5150487             -29       2
#
# [839345 rows x 3 columns]

# %%
df_label_clean['STATUS'][df_label['STATUS'] > 2] = 10
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py:992: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)

# %%
df_label_clean['STATUS'][df_label['STATUS'] <= 2] = 0
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py:992: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)

# %%
df_label_clean.groupby('STATUS')['STATUS'].count()
# Out:
# STATUS
# 0     825151
# 10     14194
# Name: STATUS, dtype: int64

# %%
df_label_group = df_label_clean.groupby('ID').mean()

# %%
df_label_group['STATUS'][df_label_group['STATUS'] > 0] = 1
df_label_group['STATUS'][df_label_group['STATUS'] <= 0] = 0

# %%
df_label_group.groupby('STATUS')['STATUS'].count()
# Out:
# STATUS
# 0.0    36099
# 1.0     5350
# Name: STATUS, dtype: int64

# %%
client_id = df_label_group.index.values
client_label = df_label_group['STATUS'].values

# %%
df.describe()
# Out:
#                  ID   CNT_CHILDREN  AMT_INCOME_TOTAL     DAYS_BIRTH  \
# count  4.385570e+05  438557.000000      4.385570e+05  438557.000000
# mean   6.022176e+06       0.427390      1.875243e+05  -15997.904649
# std    5.716370e+05       0.724882      1.100869e+05    4185.030007
# min    5.008804e+06       0.000000      2.610000e+04  -25201.000000
# 25%    5.609375e+06       0.000000      1.215000e+05  -19483.000000
# 50%    6.047745e+06       0.000000      1.607805e+05  -15630.000000
# 75%    6.456971e+06       1.000000      2.250000e+05  -12514.000000
# max    7.999952e+06      19.000000      6.750000e+06   -7489.000000
#
#        DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE     FLAG_PHONE  \
# count  438557.000000    438557.0    438557.000000  438557.000000
# mean    60563.675328         1.0         0.206133       0.287771
# std    138767.799647         0.0         0.404527       0.452724
# min    -17531.000000         1.0         0.000000       0.000000
# 25%     -3103.000000         1.0         0.000000       0.000000
# 50%     -1467.000000         1.0         0.000000       0.000000
# 75%      -371.000000         1.0         0.000000       1.000000
# max    365243.000000         1.0         1.000000       1.000000
#
#           FLAG_EMAIL  CNT_FAM_MEMBERS
# count  438557.000000    438557.000000
# mean        0.108207         2.194465
# std         0.310642         0.897207
# min         0.000000         1.000000
# 25%         0.000000         2.000000
# 50%         0.000000         2.000000
# 75%         0.000000         3.000000
# max         1.000000        20.000000

# %%
X_clien_id = df_clean_drop['ID'].values
df_clean_drop = df_clean_drop.drop(['ID'], axis = 1)

# %%
X = df_clean_drop.values
X.shape
# Out:
# (304354, 11)

# %%
real_client_id = [item for item in X_clien_id if item in client_id]

# %%
y = np.array([client_label[np.where(client_id == item)][0] for item in real_client_id])

# %%
X_final = [X[np.where(X_clien_id == item), :][0] for item in real_client_id]

# %%
X_real_final = np.vstack(X_final)

# %%
X_real_final.shape
# Out:
# (22737, 11)

# %%
len(y)
# Out:
# 22737

# %%
sum(y==0)
# Out:
# 19648

# %%
sum(y==1)
# Out:
# 3089

# %% [markdown]
# # Imbalance Problem !!

# %%
from imblearn.under_sampling import RandomUnderSampler
sm = RandomUnderSampler(random_state=0)
X_res, y_res = sm.fit_resample(X_real_final, y)

# %%
X_res.shape
# Out:
# (6178, 11)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, random_state=1)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
scaler.fit(X_train)
X_train_norm =  scaler.transform(X_train)
X_val_norm = scaler.transform(X_val)
X_test_norm = scaler.transform(X_test)

# %% [markdown]
# # Model

# %% [markdown]
# #  - LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

params = {'C': [1, 2, 4, 8, 16]}
clf = GridSearchCV(LogisticRegression(random_state=0, solver='liblinear'),params, cv=10)
clf.fit(X_train_norm, y_train)
print("Best params : " + str(clf.best_params_))
print("10CV accuracy : "+str(clf.best_score_*100))
# Out:
# Best params : {'C': 8}
# 10CV accuracy : 50.54392021480629

# %%
y_predict = clf.predict(X_test_norm)
print("Test accuracy : "+str(sum(y_test == y_predict)/len(y_test)*100))
# Out:
# Test accuracy : 51.05177993527508

# %% [markdown]
# # - Deep Learning

# %%
import tensorflow as tf

# %%
tf.compat.v1.reset_default_graph() # Clear Model
np.random.seed(1) # Fix Randomness
tf.compat.v1.random.set_random_seed(1) # Fix Randomness
model = tf.keras.models.Sequential([
tf.keras.layers.Dense(1000, activation='relu', input_shape=(11,)),
tf.keras.layers.Dense(500 ,activation='relu'),
tf.keras.layers.Dense(400, activation='relu'),   
tf.keras.layers.Dense(50, activation='relu'),
tf.keras.layers.Dense(10, activation='relu'),
tf.keras.layers.Dense(1, activation='sigmoid')    
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1000)              12000
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               500500
# _________________________________________________________________
# dense_2 (Dense)              (None, 400)               200400
# _________________________________________________________________
# dense_3 (Dense)              (None, 50)                20050
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                510
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 733,471
# Trainable params: 733,471
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# **Train Model

# %%
train_acc = list()
val_acc = list()
for i in range(0,500):
  history = model.fit(X_train_norm, y_train, epochs= 1, batch_size = 550, validation_data= (X_val_norm, y_val))
  tmp_avg = np.mean(history.history['accuracy'])
  tmp_avg_val = np.mean(history.history['val_accuracy'])
  train_acc.append(tmp_avg)
  val_acc.append(tmp_avg_val)
# Out:
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 1s 159us/sample - loss: 0.6932 - accuracy: 0.5001 - val_loss: 0.6931 - val_accuracy: 0.5076
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 58us/sample - loss: 0.6938 - accuracy: 0.4961 - val_loss: 0.6931 - val_accuracy: 0.4944
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 58us/sample - loss: 0.6931 - accuracy: 0.5032 - val_loss: 0.6931 - val_accuracy: 0.5116
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.6933 - accuracy: 0.5014 - val_loss: 0.6931 - val_accuracy: 0.4995
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 58us/sample - loss: 0.6930 - accuracy: 0.5022 - val_loss: 0.6932 - val_accuracy: 0.5106
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.6930 - accuracy: 0.5065 - val_loss: 0.6935 - val_accuracy: 0.4985
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.6936 - accuracy: 0.5047 - val_loss: 0.6930 - val_accuracy: 0.5066
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.6931 - accuracy: 0.4978 - val_loss: 0.6930 - val_accuracy: 0.5086
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 58us/sample - loss: 0.6930 - accuracy: 0.5009 - val_loss: 0.6930 - val_accuracy: 0.5025
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 58us/sample - loss: 0.6930 - accuracy: 0.5037 - val_loss: 0.6929 - val_accuracy: 0.5076
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.6931 - accuracy: 0.5082 - val_loss: 0.6928 - val_accuracy: 0.5106
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.6930 - accuracy: 0.5080 - val_loss: 0.6927 - val_accuracy: 0.5106
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.6928 - accuracy: 0.5032 - val_loss: 0.6927 - val_accuracy: 0.5187
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.6928 - accuracy: 0.5090 - val_loss: 0.6929 - val_accuracy: 0.4944
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.6926 - accuracy: 0.5254 - val_loss: 0.6930 - val_accuracy: 0.5005
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 56us/sample - loss: 0.6931 - accuracy: 0.5054 - val_loss: 0.6926 - val_accuracy: 0.5268
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.6927 - accuracy: 0.5186 - val_loss: 0.6930 - val_accuracy: 0.5066
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.6928 - accuracy: 0.5082 - val_loss: 0.6929 - val_accuracy: 0.5177
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 56us/sample - loss: 0.6925 - accuracy: 0.5062 - val_loss: 0.6930 - val_accuracy: 0.5177
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.6927 - accuracy: 0.5011 - val_loss: 0.6938 - val_accuracy: 0.5137
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 58us/sample - loss: 0.6926 - accuracy: 0.5110 - val_loss: 0.6933 - val_accuracy: 0.5177
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.6922 - accuracy: 0.5095 - val_loss: 0.6932 - val_accuracy: 0.5076
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.6920 - accuracy: 0.5178 - val_loss: 0.6938 - val_accuracy: 0.4985
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.6915 - accuracy: 0.5247 - val_loss: 0.6939 - val_accuracy: 0.5157
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 58us/sample - loss: 0.6923 - accuracy: 0.5042 - val_loss: 0.6935 - val_accuracy: 0.5187
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 59us/sample - loss: 0.6917 - accuracy: 0.5231 - val_loss: 0.6940 - val_accuracy: 0.5046
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 56us/sample - loss: 0.6911 - accuracy: 0.5204 - val_loss: 0.6932 - val_accuracy: 0.5025
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.6912 - accuracy: 0.5262 - val_loss: 0.6939 - val_accuracy: 0.5066
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 58us/sample - loss: 0.6919 - accuracy: 0.5247 - val_loss: 0.6935 - val_accuracy: 0.5086
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.6909 - accuracy: 0.5259 - val_loss: 0.6944 - val_accuracy: 0.5035
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.6910 - accuracy: 0.5191 - val_loss: 0.6949 - val_accuracy: 0.5197
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 56us/sample - loss: 0.6910 - accuracy: 0.5214 - val_loss: 0.6944 - val_accuracy: 0.5035
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.6909 - accuracy: 0.5282 - val_loss: 0.6950 - val_accuracy: 0.5046
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.6918 - accuracy: 0.5196 - val_loss: 0.6953 - val_accuracy: 0.4995
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.6910 - accuracy: 0.5183 - val_loss: 0.6946 - val_accuracy: 0.5137
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 58us/sample - loss: 0.
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 56us/sample - loss: 0.6195 - accuracy: 0.6289 - val_loss: 0.7083 - val_accuracy: 0.5753
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 56us/sample - loss: 0.6154 - accuracy: 0.6380 - val_loss: 0.7158 - val_accuracy: 0.5854
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.6098 - accuracy: 0.6420 - val_loss: 0.7390 - val_accuracy: 0.5652
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 56us/sample - loss: 0.6100 - accuracy: 0.6350 - val_loss: 0.7480 - val_accuracy: 0.5622
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 56us/sample - loss: 0.6070 - accuracy: 0.6542 - val_loss: 0.7497 - val_accuracy: 0.5632
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 56us/sample - loss: 0.6109 - accuracy: 0.6274 - val_loss: 0.7340 - val_accuracy: 0.5672
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 56us/sample - loss: 0.6118 - accuracy: 0.6365 - val_loss: 0.7480 - val_accuracy: 0.5571
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.6112 - accuracy: 0.6256 - val_loss: 0.7403 - val_accuracy: 0.5632
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 58us/sample - loss: 0.6061 - accuracy: 0.6375 - val_loss: 0.7382 - val_accuracy: 0.5824
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.6033 - accuracy: 0.6456 - val_loss: 0.7604 - val_accuracy: 0.5612
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 56us/sample - loss: 0.6043 - accuracy: 0.6405 - val_loss: 0.7575 - val_accuracy: 0.5703
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.6004 - accuracy: 0.6532 - val_loss: 0.7504 - val_accuracy: 0.5642
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 56us/sample - loss: 0.6113 - accuracy: 0.6375 - val_loss: 0.7463 - val_accuracy: 0.5753
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.6057 - accuracy: 0.6504 - val_loss: 0.7544 - val_accuracy: 0.5814
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 56us/sample - loss: 0.6038 - accuracy: 0.6441 - val_loss: 0.7469 - val_accuracy: 0.5672
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.5993 - accuracy: 0.6544 - val_loss: 0.7533 - val_accuracy: 0.5662
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.5969 - accuracy: 0.6544 - val_loss: 0.7645 - val_accuracy: 0.5763
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.6000 - accuracy: 0.6534 - val_loss: 0.7547 - val_accuracy: 0.5592
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 56us/sample - loss: 0.6049 - accuracy: 0.6388 - val_loss: 0.7566 - val_accuracy: 0.5733
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.6061 - accuracy: 0.6428 - val_loss: 0.7538 - val_accuracy: 0.5662
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.5996 - accuracy: 0.6534 - val_loss: 0.7541 - val_accuracy: 0.5723
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.6018 - accuracy: 0.6509 - val_loss: 0.7622 - val_accuracy: 0.5723
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 56us/sample - loss: 0.5973 - accuracy: 0.6630 - val_loss: 0.7534 - val_accuracy: 0.5794
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.6012 - accuracy: 0.6517 - val_loss: 0.7477 - val_accuracy: 0.5885
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.5992 - accuracy: 0.6532 - val_loss: 0.7644 - val_accuracy: 0.5895
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.5950 - accuracy: 0.6547 - val_loss: 0.7613 - val_accuracy: 0.5784
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 58us/sample - loss: 0.5953 - accuracy: 0.6504 - val_loss: 0.7637 - val_accuracy: 0.5723
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 56us/sample - loss: 0.5910 - accuracy: 0.6572 - val_loss: 0.7475 - val_accuracy: 0.5672
# Train on 3953 samples, validate on 989 samples
# ...
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.4939 - accuracy: 0.7369 - val_loss: 0.9302 - val_accuracy: 0.5774
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.4864 - accuracy: 0.7407 - val_loss: 0.8940 - val_accuracy: 0.5865
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 56us/sample - loss: 0.4853 - accuracy: 0.7372 - val_loss: 0.9249 - val_accuracy: 0.5945
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.4905 - accuracy: 0.7379 - val_loss: 0.9495 - val_accuracy: 0.5945
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 56us/sample - loss: 0.5094 - accuracy: 0.7248 - val_loss: 0.9364 - val_accuracy: 0.5915
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.4914 - accuracy: 0.7336 - val_loss: 0.9328 - val_accuracy: 0.6006
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.4833 - accuracy: 0.7382 - val_loss: 0.9225 - val_accuracy: 0.5945
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 64us/sample - loss: 0.4875 - accuracy: 0.7367 - val_loss: 0.9338 - val_accuracy: 0.6016
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.4799 - accuracy: 0.7430 - val_loss: 0.9467 - val_accuracy: 0.5915
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.4878 - accuracy: 0.7250 - val_loss: 0.9313 - val_accuracy: 0.6016
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 58us/sample - loss: 0.4829 - accuracy: 0.7410 - val_loss: 0.9302 - val_accuracy: 0.5966
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 63us/sample - loss: 0.4756 - accuracy: 0.7488 - val_loss: 0.9717 - val_accuracy: 0.5915
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 59us/sample - loss: 0.4611 - accuracy: 0.7584 - val_loss: 1.0149 - val_accuracy: 0.5834
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 58us/sample - loss: 0.4730 - accuracy: 0.7427 - val_loss: 0.9832 - val_accuracy: 0.5753
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.4738 - accuracy: 0.7488 - val_loss: 0.9832 - val_accuracy: 0.5824
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 56us/sample - loss: 0.4693 - accuracy: 0.7493 - val_loss: 0.9932 - val_accuracy: 0.5945
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 56us/sample - loss: 0.4555 - accuracy: 0.7539 - val_loss: 0.9841 - val_accuracy: 0.5956
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.4698 - accuracy: 0.7458 - val_loss: 0.9884 - val_accuracy: 0.5986
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.4679 - accuracy: 0.7485 - val_loss: 0.9989 - val_accuracy: 0.5814
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.4575 - accuracy: 0.7587 - val_loss: 0.9767 - val_accuracy: 0.6016
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 58us/sample - loss: 0.4646 - accuracy: 0.7493 - val_loss: 0.9940 - val_accuracy: 0.6138
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 56us/sample - loss: 0.4601 - accuracy: 0.7597 - val_loss: 0.9866 - val_accuracy: 0.6107
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 56us/sample - loss: 0.4522 - accuracy: 0.7579 - val_loss: 0.9794 - val_accuracy: 0.6016
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.4717 - accuracy: 0.7508 - val_loss: 0.9935 - val_accuracy: 0.5996
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.4636 - accuracy: 0.7564 - val_loss: 1.0140 - val_accuracy: 0.5814
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 68us/sample - loss: 0.4537 - accuracy: 0.7544 - val_loss: 0.9864 - val_accuracy: 0.5925
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 77us/sample - loss: 0.4564 - accuracy: 0.7582 - val_loss: 1.0198 - val_accuracy: 0.6006
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 76us/sample - loss: 0.4527 - accuracy: 0.7620 - val_loss: 0.9708 - val_accuracy: 0.6087
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 73us/sample - loss: 0.4595 - accuracy: 0.7640 - val_loss: 0.9933 - val_accuracy: 0.6036
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 67us/sample - loss: 0.4604 - accuracy: 0.7592 - val_loss: 0.9903 - val_accuracy: 0.5865
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.4636 - accuracy: 0.7541 - val_loss: 1.0179 - val_accuracy: 0.6107
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 56us/sample - loss: 0.4582 - accuracy: 0.7622 - val_loss: 1.0097 - val_accuracy: 0.5794
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 56us/sample - loss: 0.4546 - accuracy: 0.7678 - val_loss: 1.0261 - val_accuracy: 0.5875
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 56us/sample - loss: 0.4576 - accuracy: 0.7566 - val_loss: 0.9965 - val_accuracy: 0.6006
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 56us/sample - loss: 0.4563 - accuracy: 0.7733 - val_loss: 1.0233 - val_accuracy: 0.5895
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 56us/sample - loss: 0.4587 - accuracy: 0.7554 - val_loss: 0.9841 - val_accuracy: 0.5925
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 58us/sample - loss: 0.4593 - accuracy: 0.7632 - val_loss: 1.0126 - val_accuracy: 0.5945
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 56us/sample - loss: 0.4585 - accuracy: 0.7607 - val_loss: 1.0002 - val_accuracy: 0.5865
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 56us/sample - loss: 0.4583 - accuracy: 0.7559 - val_loss: 1.0168 - val_accuracy: 0.5956
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 56us/sample - loss: 0.4483 - accuracy: 0.7622 - val_loss: 0.9973 - val_accuracy: 0.6006
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.4471 - accuracy: 0.7673 - val_loss: 0.9990 - val_accuracy: 0.5996
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.4600 - accuracy: 0.7531 - val_loss: 1.0148 - val_accuracy: 0.6006
# Train on 3953 samples, validate on 989 samples
# 3953/3953 [==============================] - 0s 57us/sample - loss: 0.4595 - accuracy: 0.7612 - val_loss: 0.9978 - val_accuracy: 0.5925

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
plt.figure(num=None, figsize=(16, 8), dpi=90, facecolor='w', edgecolor='k')
plt.plot()
plt.plot(train_acc)
plt.plot(val_acc)
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
y_predict = np.round(model.predict(X_test_norm))
y_predict = [i[0] for i in y_predict.tolist()]
sum(y_predict == y_test)/len(y_test)
# Out:
# 0.6043689320388349
